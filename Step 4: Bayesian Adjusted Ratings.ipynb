# %% [markdown]
# ###  Bayeisian averaging adjustment for five star rating system

# %%
import os
import heapq

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from collections import Counter
from operator import itemgetter

# %%
os.chdir('/Users/lurui/Desktop')

# %%
data=pd.read_csv("/Users/lurui/Desktop/Insight/overall.data.csv")

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'Name', 'Speciality', 'Star Rating', 'Staff',
#        'Punctuality', 'Helpfulness', 'Knowledge', 'comment',
#        'Rating Usefulness', 'Review Date', 'Link', 'text_length',
#        'trim_comment', 'neg', 'neu', 'pos', 'compound', 'polarity',
#        'subjectivity', 'Document_No', 'Dominant_Topic', 'Topic_Perc_Contrib',
#        'Keywords', 'Text', 'Positive Sentiment', 'Negative Sentiment'],
#       dtype='object')

# %%
data.head(5)
# Out:
#    Unnamed: 0                 Name            Speciality  Star Rating  Staff  \
# 0           0  Dr. Natan Schleider  Family Doctor / G.P.          5.0      5
# 1           1  Dr. Natan Schleider  Family Doctor / G.P.          5.0      5
# 2           2  Dr. Natan Schleider  Family Doctor / G.P.          5.0      5
# 3           3  Dr. Natan Schleider  Family Doctor / G.P.          5.0      5
# 4           4  Dr. Natan Schleider  Family Doctor / G.P.          4.0      5
#
#    Punctuality  Helpfulness  Knowledge  \
# 0          5.0            5        5.0
# 1          5.0            5        5.0
# 2          5.0            5        5.0
# 3          5.0            5        5.0
# 4          5.0            5        1.0
#
#                                              comment Rating Usefulness  ...  \
# 0  I thought   was extremely caring and attentive...             ['0']  ...
# 1    was friendly, punctual, and super nice. He e...             ['0']  ...
# 2  My experience with   was the opposite of every...             ['0']  ...
# 3  very good. Very knowledgeable and friendly wit...             ['0']  ...
# 4    is very knowledgeable and friendly with an e...             ['0']  ...
#
#   compound  polarity  subjectivity Document_No  Dominant_Topic  \
# 0   0.8883  0.233750      0.818333           0             2.0
# 1   0.8748  0.227083      0.377381           1             2.0
# 2   0.9118  0.000000      0.000000           2             2.0
# 3   0.7506  0.375000      0.500000           3             2.0
# 4   0.7506  0.375000      0.500000           4             2.0
#
#    Topic_Perc_Contrib                                           Keywords  \
# 0              0.3777  staff, care, doctor, patient, office, time, go...
# 1              0.3602  staff, care, doctor, patient, office, time, go...
# 2              0.3879  staff, care, doctor, patient, office, time, go...
# 3              0.3933  staff, care, doctor, patient, office, time, go...
# 4              0.3933  staff, care, doctor, patient, office, time, go...
#
#                                                 Text  Positive Sentiment  \
# 0  ['think', 'extremely', 'care', 'attentive', 'n...                True
# 1  ['friendly', 'punctual', 'super', 'email', 'la...                True
# 2  ['experience', 'doctor', 'past_experiences', '...                True
# 3  ['knowledgeable', 'friendly', 'manner', 'highl...                True
# 4  ['knowledgeable', 'friendly', 'manner', 'highl...                True
#
#    Negative Sentiment
# 0               False
# 1               False
# 2               False
# 3               False
# 4               False
#
# [5 rows x 27 columns]

# %%
ratings=data[["Name","Star Rating","Staff","Punctuality","Helpfulness","Knowledge"]].dropna()

# %%
ratings.shape
# Out:
# (12529, 6)

# %%
ratings
# Out:
#                          Name  Star Rating  Staff  Punctuality  Helpfulness  \
# 0         Dr. Natan Schleider         5.00      5          5.0            5
# 1         Dr. Natan Schleider         5.00      5          5.0            5
# 2         Dr. Natan Schleider         5.00      5          5.0            5
# 3         Dr. Natan Schleider         5.00      5          5.0            5
# 4         Dr. Natan Schleider         4.00      5          5.0            5
# ...                       ...          ...    ...          ...          ...
# 12524  Dr. Douglas A. Taranow         1.50      5          5.0            5
# 12525  Dr. Douglas A. Taranow         2.75      5          4.0            5
# 12526  Dr. Douglas A. Taranow         5.00      5          4.0            5
# 12527  Dr. Douglas A. Taranow         5.00      0          5.0            5
# 12528  Dr. Douglas A. Taranow         5.00      0          3.0            5
#
#        Knowledge
# 0            5.0
# 1            5.0
# 2            5.0
# 3            5.0
# 4            1.0
# ...          ...
# 12524        5.0
# 12525        5.0
# 12526        5.0
# 12527        5.0
# 12528        5.0
#
# [12529 rows x 6 columns]

# %%
ratings.to_csv('ratings.csv', index=False)

# %% [markdown]
# ### Bayesian Model Averaging Class

# %%
PATH= os.path.join(os.path.dirname("/Users/lurui/"), 'Desktop/Insight/ratings.csv')
PRIOR = [2.5, 2.5, 2.5, 2.5, 2.5] ### uniform prior

# %%
class Ratings(object):
    """
    An analytical wrapper that manages access to the data and wraps various
    statistical functions for easy and quick evaluation.
    """

    def __init__(self, path=PATH, m=None, C=None):
        self.path  = path
        self.prior = m
        self.confidence = C
        self.load()

    def load(self):
        """
        Load data from disk into a DataFrame.
        """
        self.data = pd.DataFrame(pd.read_csv(self.path))

    def bayesian_mean(self, arr):
        """
        Computes the Bayesian mean from the prior and confidence.
        """
        if not self.prior or not self.confidence:
            raise TypeError("Bayesian mean must be computed with m and C")

        return (self.confidence * self.prior + arr.sum()) / (self.confidence + arr.count())

    @property
    def doctors(self):
        """
        Returns the data grouped by Movie
        """
        return self.data.groupby('Name')

    def get_means(self):
        return self.doctors['Star Rating'].mean()

    def get_counts(self):
        return self.doctors['Star Rating'].count()

    def get_bayesian_estimates(self):
        return self.doctors['Star Rating'].agg(self.bayesian_mean)

    def top_doctors(self, n=1000):
        grid   = pd.DataFrame({
                    'mean':  self.get_means(),
                    'count': self.get_counts(),
                    'bayes': self.get_bayesian_estimates()})
        return (grid.iloc[grid['bayes'].argsort()[-n:]])

if __name__ == '__main__':
    over_all_ratings=[]
    ratings = Ratings(m=4.0, C=10) ### confidence 10 with prior 4
    over_all_ratings.append(ratings.top_doctors())

# %%
adjusted_rating_data=pd.DataFrame(over_all_ratings[0])

# %%
adjusted_rating_data
# Out:
#                              mean  count     bayes
# Name
# Dr. Cherry Ostrager      2.744444     45  2.972727
# Dr. Tamara Guichard      2.312500     12  3.079545
# Dr. Megan Thomasch       2.772727     11  3.357143
# Dr. Michael H. Aziz      3.243056     36  3.407609
# Dr. Raymond J. Walls     2.875000     10  3.437500
# ...                           ...    ...       ...
# Dr. Imad E. Ayoubi       5.000000     85  4.894737
# Dr. Shu Ping Rong        4.956522    161  4.900585
# Dr. Andrew D. Frangella  5.000000    106  4.913793
# Dr. Lesley Rabach        5.000000    112  4.918033
# Dr. Mazen Natour         4.997619    525  4.978972
#
# [530 rows x 3 columns]

# %%
### Before adjustment 
adjusted_rating_data["mean"].hist(bins=50)

# %%
### After adjustment 
adjusted_rating_data["bayes"].hist(bins=50)

# %%
import os
os.chdir('/Users/lurui/Desktop/Insight')

# %%
adjusted_rating_data

# %%
adjusted_rating_data.to_csv(r'adjusted_rating_data.csv', encoding='utf8')
