# %% [markdown]
# ###  Step 1: Identify the specialties of the NYC doctor

# %%
import requests,re
import pandas
from bs4 import BeautifulSoup
import time

# %%
import pandas as pd

# %%
def identify_specialities(base_url="https://www.ratemds.com/ny/newyork/"):
    l=[]
    specialities=[]
    base_url=base_url
    burl=requests.get(base_url)
    cont=burl.content
    basesoup=BeautifulSoup(cont,"html.parser")
    for ul in basesoup.findAll('ul', class_='nav home-specialties-nav hidden-xs'):
        for link in ul.findAll("li"):
            try:
                ngattr= link.attrs["ng-class"]
                spec = ngattr.split("==")[1].replace('}','').replace("'","")
            except:
                spec=None
            specialities.append(spec)
    specialities.remove(None)
    return(specialities)

# %%
specialities=identify_specialities(base_url="https://www.ratemds.com/ny/newyork/")

# %%
specialities
# Out:
# ['family-gp',
#  'gynecologist-obgyn',
#  'dentist',
#  'orthopedics-sports',
#  'internist-geriatrician',
#  'cosmetic-plastic-surgeon',
#  'dermatologist',
#  'psychologist',
#  'psychiatrist',
#  'chiropractor',
#  'surgeon-general',
#  'ear-nose-and-throat-ent',
#  'pediatrician']

# %%
l=[]
pages = [10,10,10,10,10,10,10,10,10,10,10,10,10]
base_url_start="https://www.ratemds.com/best-doctors/ny/new-york/"
base_url_end="/?page="
for speciality,page in zip(specialities, pages):
    for p in range(1, page+1, 1):
        print(base_url_start + speciality + base_url_end + str(p))
        r=requests.get(base_url_start + speciality+base_url_end + str(p))
        c=r.content
        soup=BeautifulSoup(c,"html.parser")
        all=soup.find_all("div",{"class":"search-item doctor-profile"})
        for item in all:
            d={}
            try:
                d["Name"]=item.find("a",{"class":"search-item-doctor-link"}).text.replace("\n","")
            except:
                d["Name"]=None
            try:
                d["Link"]= "ratemds.com" + item.find("a",{"class":"search-item-doctor-link"}).attrs["href"]
            except:
                d["Link"]=None
            try:
                d["Speciality"]=item.find("div",{"class":"search-item-specialty"}).text.replace("\n","")
            except:
                d["Speciality"]=None
            try:
                d["Rating"]=item.find("span",{"class":"star-rating"}).attrs["title"]
            except:
                d["Rating"]=None
            try:
                d["Reviews Count"]=item.find("div",{"class":"star-rating-count"}).text.split()[0]
            except:
                d["Reviews Count"]=None
            try:
                d["Comment"]=item.find("p",{"class":"rating-comment"}).text

            except:
                d["Comment"]=None
            l.append(d)
# Out:
# https://www.ratemds.com/best-doctors/ny/new-york/family-gp/?page=1
# https://www.ratemds.com/best-doctors/ny/new-york/family-gp/?page=2
# https://www.ratemds.com/best-doctors/ny/new-york/family-gp/?page=3
# https://www.ratemds.com/best-doctors/ny/new-york/family-gp/?page=4
# https://www.ratemds.com/best-doctors/ny/new-york/family-gp/?page=5
# https://www.ratemds.com/best-doctors/ny/new-york/family-gp/?page=6
# https://www.ratemds.com/best-doctors/ny/new-york/family-gp/?page=7
# https://www.ratemds.com/best-doctors/ny/new-york/family-gp/?page=8
# https://www.ratemds.com/best-doctors/ny/new-york/family-gp/?page=9
# https://www.ratemds.com/best-doctors/ny/new-york/family-gp/?page=10
# https://www.ratemds.com/best-doctors/ny/new-york/gynecologist-obgyn/?page=1
# https://www.ratemds.com/best-doctors/ny/new-york/gynecologist-obgyn/?page=2
# https://www.ratemds.com/best-doctors/ny/new-york/gynecologist-obgyn/?page=3
# https://www.ratemds.com/best-doctors/ny/new-york/gynecologist-obgyn/?page=4
# https://www.ratemds.com/best-doctors/ny/new-york/gynecologist-obgyn/?page=5
# https://www.ratemds.com/best-doctors/ny/new-york/gynecologist-obgyn/?page=6
# https://www.ratemds.com/best-doctors/ny/new-york/gynecologist-obgyn/?page=7
# https://www.ratemds.com/best-doctors/ny/new-york/gynecologist-obgyn/?page=8
# https://www.ratemds.com/best-doctors/ny/new-york/gynecologist-obgyn/?page=9
# https://www.ratemds.com/best-doctors/ny/new-york/gynecologist-obgyn/?page=10
# https://www.ratemds.com/best-doctors/ny/new-york/dentist/?page=1
# https://www.ratemds.com/best-doctors/ny/new-york/dentist/?page=2
# https://www.ratemds.com/best-doctors/ny/new-york/dentist/?page=3
# https://www.ratemds.com/best-doctors/ny/new-york/dentist/?page=4
# https://www.ratemds.com/best-doctors/ny/new-york/dentist/?page=5
# https://www.ratemds.com/best-doctors/ny/new-york/dentist/?page=6
# https://www.ratemds.com/best-doctors/ny/new-york/dentist/?page=7
# https://www.ratemds.com/best-doctors/ny/new-york/dentist/?page=8
# https://www.ratemds.com/best-doctors/ny/new-york/dentist/?page=9
# https://www.ratemds.com/best-doctors/ny/new-york/dentist/?page=10
# https://www.ratemds.com/best-doctors/ny/new-york/orthopedics-sports/?page=1
# https://www.ratemds.com/best-doctors/ny/new-york/orthopedics-sports/?page=2
# https://www.ratemds.com/best-doctors/ny/new-york/orthopedics-sports/?page=3
# https://www.ratemds.com/best-doctors/ny/new-york/orthopedics-sports/?page=4
# https://www.ratemds.com/best-doctors/ny/new-york/orthopedics-sports/?page=5
# https://www.ratemds.com/best-doctors/ny/new-york/orthopedics-sports/?page=6
# https://www.ratemds.com/best-doctors/ny/new-york/orthopedics-sports/?page=7
# https://www.ratemds.com/best-doctors/ny/new-york/orthopedics-sports/?page=8
# https://www.ratemds.com/best-doctors/ny/new-york/orthopedics-sports/?page=9
# https://www.ratemds.com/best-doctors/ny/new-york/orthopedics-sports/?page=10
# https://www.ratemds.com/best-doctors/ny/new-york/internist-geriatrician/?page=1
# https://www.ratemds.com/best-doctors/ny/new-york/internist-geriatrician/?page=2
# https://www.ratemds.com/best-doctors/ny/new-york/internist-geriatrician/?page=3
# https://www.ratemds.com/best-doctors/ny/new-york/internist-geriatrician/?page=4
# https://www.ratemds.com/best-doctors/ny/new-york/internist-geriatrician/?page=5
# https://www.ratemds.com/best-doctors/ny/new-york/internist-geriatrician/?page=6
# https://www.ratemds.com/best-doctors/ny/new-york/internist-geriatrician/?page=7
# https://www.ratemds.com/best-doctors/ny/new-york/internist-geriatrician/?page=8
# https://www.ratemds.com/best-doctors/ny/new-york/internist-geriatrician/?page=9
# https://www.ratemds.com/best-doctors/ny/new-york/internist-geriatrician/?page=10
# https://www.ratemds.com/best-doctors/ny/new-york/cosmetic-plastic-surgeon/?page=1
# https://www.ratemds.com/best-doctors/ny/new-york/cosmetic-plastic-surgeon/?page=2
# https://www.ratemds.com/best-doctors/ny/new-york/cosmetic-plastic-surgeon/?page=3
# https://www.ratemds.com/best-doctors/ny/new-york/cosmetic-plastic-surgeon/?page=4
# https://www.ratemds.com/best-doctors/ny/new-york/cosmetic-plastic-surgeon/?page=5
# https://www.ratemds.com/best-doctors/ny/new-york/cosmetic-plastic-surgeon/?page=6
# https://www.ratemds.com/best-doctors/ny/new-york/cosmetic-plastic-surgeon/?page=7
# https://www.ratemds.com/best-doctors/ny/new-york/cosmetic-plastic-surgeon/?page=8
# https://www.ratemds.com/best-doctors/ny/new-york/cosmetic-plastic-surgeon/?page=9
# https://www.ratemds.com/best-doctors/ny/new-york/cosmetic-plastic-surgeon/?page=10
# https://www.ratemds.com/best-doctors/ny/new-york/dermatologist/?page=1
# https://www.ratemds.com/best-doctors/ny/new-york/dermatologist/?page=2
# https://www.ratemds.com/best-doctors/ny/new-york/dermatologist/?page=3
# https://www.ratemds.com/best-doctors/ny/new-york/dermatologist/?page=4
# https://www.ratemds.com/best-doctors/ny/new-york/dermatologist/?page=5
# https://www.ratemds.com/best-doctors/ny/new-york/dermatologist/?page=6
# https://www.ratemds.com/best-doctors/ny/new-york/dermatologist/?page=7
# https://www.ratemds.com/best-doctors/ny/new-york/dermatologist/?page=8
# https://www.ratemds.com/best-doctors/ny/new-york/dermatologist/?page=9
# https://www.ratemds.com/best-doctors/ny/new-york/dermatologist/?page=10
# https://www.ratemds.com/best-doctors/ny/new-york/psychologist/?page=1
# https://www.ratemds.com/best-doctors/ny/new-york/psychologist/?page=2
# https://www.ratemds.com/best-doctors/ny/new-york/psychologist/?page=3
# https://www.ratemds.com/best-doctors/ny/new-york/psychologist/?page=4
# https://www.ratemds.com/best-doctors/ny/new-york/psychologist/?page=5
# https://www.ratemds.com/best-doctors/ny/new-york/psychologist/?page=6
# https://www.ratemds.com/best-doctors/ny/new-york/psychologist/?page=7
# https://www.ratemds.com/best-doctors/ny/new-york/psychologist/?page=8
# https://www.ratemds.com/best-doctors/ny/new-york/psychologist/?page=9
# https://www.ratemds.com/best-doctors/ny/new-york/psychologist/?page=10
# https://www.ratemds.com/best-doctors/ny/new-york/psychiatrist/?page=1
# https://www.ratemds.com/best-doctors/ny/new-york/psychiatrist/?page=2
# https://www.ratemds.com/best-doctors/ny/new-york/psychiatrist/?page=3
# https://www.ratemds.com/best-doctors/ny/new-york/psychiatrist/?page=4
# https://www.ratemds.com/best-doctors/ny/new-york/psychiatrist/?page=5
# https://www.ratemds.com/best-doctors/ny/new-york/psychiatrist/?page=6
# https://www.ratemds.com/best-doctors/ny/new-york/psychiatrist/?page=7
# https://www.ratemds.com/best-doctors/ny/new-york/psychiatrist/?page=8
# https://www.ratemds.com/best-doctors/ny/new-york/psychiatrist/?page=9
# https://www.ratemds.com/best-doctors/ny/new-york/psychiatrist/?page=10
# https://www.ratemds.com/best-doctors/ny/new-york/chiropractor/?page=1
# https://www.ratemds.com/best-doctors/ny/new-york/chiropractor/?page=2
# https://www.ratemds.com/best-doctors/ny/new-york/chiropractor/?page=3
# https://www.ratemds.com/best-doctors/ny/new-york/chiropractor/?page=4
# https://www.ratemds.com/best-doctors/ny/new-york/chiropractor/?page=5
# https://www.ratemds.com/best-doctors/ny/new-york/chiropractor/?page=6
# https://www.ratemds.com/best-doctors/ny/new-york/chiropractor/?page=7
# https://www.ratemds.com/best-doctors/ny/new-york/chiropractor/?page=8
# https://www.ratemds.com/best-doctors/ny/new-york/chiropractor/?page=9
# https://www.ratemds.com/best-doctors/ny/new-york/chiropractor/?page=10
# https://www.ratemds.com/best-doctors/ny/new-york/surgeon-general/?page=1
# https://www.ratemds.com/best-doctors/ny/new-york/surgeon-general/?page=2
# https://www.ratemds.com/best-doctors/ny/new-york/surgeon-general/?page=3
# https://www.ratemds.com/best-doctors/ny/new-york/surgeon-general/?page=4
# https://www.ratemds.com/best-doctors/ny/new-york/surgeon-general/?page=5
# https://www.ratemds.com/best-doctors/ny/new-york/surgeon-general/?page=6
# https://www.ratemds.com/best-doctors/ny/new-york/surgeon-general/?page=7
# https://www.ratemds.com/best-doctors/ny/new-york/surgeon-general/?page=8
# https://www.ratemds.com/best-doctors/ny/new-york/surgeon-general/?page=9
# https://www.ratemds.com/best-doctors/ny/new-york/surgeon-general/?page=10
# https://www.ratemds.com/best-doctors/ny/new-york/ear-nose-and-throat-ent/?page=1
# https://www.ratemds.com/best-doctors/ny/new-york/ear-nose-and-throat-ent/?page=2
# https://www.ratemds.com/best-doctors/ny/new-york/ear-nose-and-throat-ent/?page=3
# https://www.ratemds.com/best-doctors/ny/new-york/ear-nose-and-throat-ent/?page=4
# https://www.ratemds.com/best-doctors/ny/new-york/ear-nose-and-throat-ent/?page=5
# https://www.ratemds.com/best-doctors/ny/new-york/ear-nose-and-throat-ent/?page=6
# https://www.ratemds.com/best-doctors/ny/new-york/ear-nose-and-throat-ent/?page=7
# https://www.ratemds.com/best-doctors/ny/new-york/ear-nose-and-throat-ent/?page=8
# https://www.ratemds.com/best-doctors/ny/new-york/ear-nose-and-throat-ent/?page=9
# https://www.ratemds.com/best-doctors/ny/new-york/ear-nose-and-throat-ent/?page=10
# https://www.ratemds.com/best-doctors/ny/new-york/pediatrician/?page=1
# https://www.ratemds.com/best-doctors/ny/new-york/pediatrician/?page=2
# https://www.ratemds.com/best-doctors/ny/new-york/pediatrician/?page=3
# https://www.ratemds.com/best-doctors/ny/new-york/pediatrician/?page=4
# https://www.ratemds.com/best-doctors/ny/new-york/pediatrician/?page=5
# https://www.ratemds.com/best-doctors/ny/new-york/pediatrician/?page=6
# https://www.ratemds.com/best-doctors/ny/new-york/pediatrician/?page=7
# https://www.ratemds.com/best-doctors/ny/new-york/pediatrician/?page=8
# https://www.ratemds.com/best-doctors/ny/new-york/pediatrician/?page=9
# https://www.ratemds.com/best-doctors/ny/new-york/pediatrician/?page=10

# %%
df=pd.DataFrame(l)

# %%
df.shape
# Out:
# (1396, 6)

# %%
df_new=df.drop_duplicates()

# %%
df_new.shape
# Out:
# (1304, 6)

# %%
df_new.head(100)
# Out:
#                               Name  \
# 0              Dr. Natan Schleider
# 1            Dr. George P. Liakeas
# 2             Dr. Tammy L. Leopold
# 3   Dr. Irina Korneeva-Vladimirsky
# 4                Dr. Lyubov Moysik
# ..                             ...
# 95                   Dr. Chao Chen
# 96             Dr. Robert M. Smith
# 97                Dr. Alan R. Roth
# 98            Dr. Emily H. Sheffer
# 99             Dr. Robert H. Geula
#
#                                                  Link            Speciality  \
# 0   ratemds.com/doctor-ratings/20189/Dr-Natan-Schl...  Family Doctor / G.P.
# 1   ratemds.com/doctor-ratings/53736/Dr-George+P.-...  Family Doctor / G.P.
# 2   ratemds.com/doctor-ratings/68700/Dr-Tammy+L.-L...  Family Doctor / G.P.
# 3   ratemds.com/doctor-ratings/3207299/Dr-Irina-Ko...  Family Doctor / G.P.
# 4   ratemds.com/doctor-ratings/2650588/Dr-LYUBOV-M...  Family Doctor / G.P.
# ..                                                ...                   ...
# 95  ratemds.com/doctor-ratings/2585085/Dr-CHAO-CHE...  Family Doctor / G.P.
# 96  ratemds.com/doctor-ratings/707713/Dr-Robert+M....  Family Doctor / G.P.
# 97  ratemds.com/doctor-ratings/18577/Dr-Alan+R.-Ro...  Family Doctor / G.P.
# 98  ratemds.com/doctor-ratings/34116/Dr-Emily+H.-S...  Family Doctor / G.P.
# 99  ratemds.com/doctor-ratings/19456/Dr-Robert+H.-...  Family Doctor / G.P.
#
#    Rating Reviews Count                                            Comment
# 0    4.92            37  I thought Dr. Schleider was extremely caring a...
# 1    4.56            33  Dr Liakes treats me, my sister, and nieces.Als...
# 2    4.56            25  Dr. Leopold was simply AWESOME. She took her t...
# 3    4.41            29  I go to her often, she’s my primary care docto...
# 4    5.00             8  She is a professional specialist in acne surge...
# ..    ...           ...                                                ...
# 95   4.88             2  Has been my PCP for 12 years!!!!!!!!!!!!!!!!!!...
# 96   4.88             2  We have been going here since my first pregnan...
# 97   4.85             5  Best doctor ever!! He and his staff have been ...
# 98   4.88             2  Emily is a Terrific Doc! Need more like her, e...
# 99   4.00             3  THE BEST CONTACT DOCTOR YOU CAN FINE IN NYC . ...
#
# [100 rows x 6 columns]

# %%
df_new.to_csv("all_specialities.csv")

# %%
import requests,re
import pandas as pd
from bs4 import BeautifulSoup
import time
import math

# %% [markdown]
# ### Step II: Create dataframe for doctors that scapped online

# %%
#Final code to extract list of all reviews in each doctor's page

staff_value = []
punctuality_value = []
helpfulness_value = []
knowledge_value = []
star_rating = []
l = []
links = []
name = []
spec = []
star_rating = []
comment = []
rating_usefulness = []
review_date = []

#you can either read from the csv created from the previous step or use the df directly
#df = pd.read_csv(r'ratemd_all_specialities.csv', encoding='utf8')

rows, col = df_new.shape

base_url_start = str("https://www.")

#Looping each doctor's link in df
for i in range(rows):
    k = i+1
    print('Doctor '+ str(k) +' is getting scraped')
    base_url = str(df.iloc[i]['Link'])
    base_url1 = str("?page=")
    
    reviews = int(df.iloc[i]['Reviews Count'])
#Extracting the number of pages for each doctor based on the number of reviews
    page_no = math.ceil(reviews/10)

    page_no += 1
#Looping over each page of each doctor in the outer loop    
    for j in range(1, page_no):
        base_url2 = str(j)
        doc_url = base_url_start + base_url + base_url1 + base_url2

        durl=requests.get(doc_url)
        dcont=durl.content
        docsoup=BeautifulSoup(dcont,"html.parser")

        alldoc = docsoup.find_all("div", class_="col-sm-7".split())
#Looping over all the div elements of class "col-sm-7" in that particular page        
        for el in alldoc:
            all_rating=el.get_text()
            links.append(doc_url)
            name.append(df.iloc[i]['Name'])
            spec.append(df.iloc[i]['Speciality'])
            try:
                staff_value.append(int(all_rating.split()[0][0]))
            except ValueError:
                staff_value.append(int(0))
            try:
                punctuality_value.append(int(all_rating.split()[1][0]))
            except ValueError:
                punctuality_value.append(int(0))
            try:
                helpfulness_value.append(int(all_rating.split()[2][0]))
            except ValueError:
                helpfulness_value.append(int(0))
            try:
                knowledge_value.append(int(all_rating.split()[3][0]))
            except ValueError:           
                knowledge_value.append(int(0))
#Looping over all the div elements of class "rating" in that particular page 
        all_star_rating=docsoup.find_all("div",{"class":"rating"})
        for item in all_star_rating:
            try:
                star_rating.append(item.find("span",{"class":"star-rating"}).attrs["title"])
            except:
                star_rating.append(0)
            try:
                comment.append(item.find("p",{"itemprop":"reviewBody"}).text)
            except:
                comment.append('NA')
            try:
                rating_usefulness.append(item.find("p",{"class":"rating-comment-votes pull-left"}).text.split()[4:])
            except:
                rating_usefulness.append(0)
            try:
                review_date.append(item.find("p",{"class":"rating-comment-created pull-right"}).text.split()[3:])
            except:
                review_date.append('NA')
        print(len(name), len(spec), len(star_rating), len(staff_value), len(punctuality_value), len(helpfulness_value),len(knowledge_value), len(comment), len(review_date), len(links))

d ={'Name': name, 'Speciality' : spec, 'Star Rating': star_rating, 'Staff': staff_value, 'Punctuality': punctuality_value, 'Helpfulness': helpfulness_value,'Knowledge': knowledge_value, 'comment': comment,'Rating Usefulness' : rating_usefulness, 'Review Date': review_date,'Link': links}

# %%
d.keys()
# Out:
# dict_keys(['Name', 'Link', 'Speciality', 'Rating', 'Reviews Count', 'Comment'])

# %%
print(len(d['Name']), len(d['Speciality']), len(d['Star Rating']))
# Out:
# 24458 24458 24915

# %%
### data set for all reviews 
k=list(d.keys())
v=list(d.values())

# %%
df_all=df = pd.DataFrame(d)

# %%
df_links.head(10)
# Out:
#                   Name            Speciality Star Rating Staff Punctuality  \
# 0  Dr. Natan Schleider  Family Doctor / G.P.        5.00     5           5
# 1  Dr. Natan Schleider  Family Doctor / G.P.        5.00     5           5
# 2  Dr. Natan Schleider  Family Doctor / G.P.        5.00     5           5
# 3  Dr. Natan Schleider  Family Doctor / G.P.        5.00     5           5
# 4  Dr. Natan Schleider  Family Doctor / G.P.        4.00     5           5
# 5  Dr. Natan Schleider  Family Doctor / G.P.        5.00     5           5
# 6  Dr. Natan Schleider  Family Doctor / G.P.        5.00     5           5
# 7  Dr. Natan Schleider  Family Doctor / G.P.        5.00     5           5
# 8  Dr. Natan Schleider  Family Doctor / G.P.        5.00     5           5
# 9  Dr. Natan Schleider  Family Doctor / G.P.        5.00     5           5
#
#   Helpfulness Knowledge                                            comment  \
# 0           5         5  I thought Dr. Schleider was extremely caring a...
# 1           5         5  Dr. Schleider was friendly, punctual, and supe...
# 2           5         5  My experience with Dr. Schleider was the oppos...
# 3           5         5  very good. Very knowledgeable and friendly wit...
# 4           5         1  Dr. Schleider is very knowledgeable and friend...
# 5           5         5  Excellent Physician with exceptional bedside m...
# 6           5         5  I've been seeing Dr Schleider for the past fiv...
# 7           5         5  Fantastic service, Friendly & Knowledgeable! I...
# 8           5         5  I am a registered nurse in NYC and worked with...
# 9           5         5  Dr. Natan Schleider is nice, professional and ...
#
#   Rating Usefulness            Review Date  \
# 0               [0]  [November, 20,, 2019]
# 1               [0]       [July, 7,, 2019]
# 2               [0]    [January, 2,, 2019]
# 3               [0]     [August, 9,, 2017]
# 4               [0]   [November, 8,, 2015]
# 5               [2]    [August, 13,, 2015]
# 6               [5]   [November, 3,, 2014]
# 7               [1]  [September, 2,, 2013]
# 8               [3]      [July, 10,, 2013]
# 9               [2]      [April, 7,, 2013]
#
#                                                 Link
# 0  https://www.ratemds.com/doctor-ratings/20189/D...
# 1  https://www.ratemds.com/doctor-ratings/20189/D...
# 2  https://www.ratemds.com/doctor-ratings/20189/D...
# 3  https://www.ratemds.com/doctor-ratings/20189/D...
# 4  https://www.ratemds.com/doctor-ratings/20189/D...
# 5  https://www.ratemds.com/doctor-ratings/20189/D...
# 6  https://www.ratemds.com/doctor-ratings/20189/D...
# 7  https://www.ratemds.com/doctor-ratings/20189/D...
# 8  https://www.ratemds.com/doctor-ratings/20189/D...
# 9  https://www.ratemds.com/doctor-ratings/20189/D...

# %%
df_links.head(100)
# Out:
#                               Name            Speciality Star Rating Staff  \
# 0              Dr. Natan Schleider  Family Doctor / G.P.        5.00     5
# 1              Dr. Natan Schleider  Family Doctor / G.P.        5.00     5
# 2              Dr. Natan Schleider  Family Doctor / G.P.        5.00     5
# 3              Dr. Natan Schleider  Family Doctor / G.P.        5.00     5
# 4              Dr. Natan Schleider  Family Doctor / G.P.        4.00     5
# ..                             ...                   ...         ...   ...
# 95  Dr. Irina Korneeva-Vladimirsky  Family Doctor / G.P.        5.00     5
# 96  Dr. Irina Korneeva-Vladimirsky  Family Doctor / G.P.        5.00     5
# 97  Dr. Irina Korneeva-Vladimirsky  Family Doctor / G.P.        5.00     5
# 98  Dr. Irina Korneeva-Vladimirsky  Family Doctor / G.P.        5.00     5
# 99  Dr. Irina Korneeva-Vladimirsky  Family Doctor / G.P.        1.00     1
#
#    Punctuality Helpfulness Knowledge  \
# 0            5           5         5
# 1            5           5         5
# 2            5           5         5
# 3            5           5         5
# 4            5           5         1
# ..         ...         ...       ...
# 95           5           5         5
# 96           5           5         5
# 97           5           5         5
# 98           5           5         5
# 99           1           1         1
#
#                                               comment Rating Usefulness  \
# 0   I thought Dr. Schleider was extremely caring a...               [0]
# 1   Dr. Schleider was friendly, punctual, and supe...               [0]
# 2   My experience with Dr. Schleider was the oppos...               [0]
# 3   very good. Very knowledgeable and friendly wit...               [0]
# 4   Dr. Schleider is very knowledgeable and friend...               [0]
# ..                                                ...               ...
# 95  I go to her often, she’s my primary care docto...               [1]
# 96  very effective and if she cant diagnose nobody...               [2]
# 97  On behalf of myself and my entire family, I wo...               [1]
# 98  This doctor is amazing. She always answers all...               [1]
# 99  Horrible Dr.\nDr Korneeva Vladermirsky,preform...               [1]
#
#               Review Date                                               Link
# 0   [November, 20,, 2019]  https://www.ratemds.com/doctor-ratings/20189/D...
# 1        [July, 7,, 2019]  https://www.ratemds.com/doctor-ratings/20189/D...
# 2     [January, 2,, 2019]  https://www.ratemds.com/doctor-ratings/20189/D...
# 3      [August, 9,, 2017]  https://www.ratemds.com/doctor-ratings/20189/D...
# 4    [November, 8,, 2015]  https://www.ratemds.com/doctor-ratings/20189/D...
# ..                    ...                                                ...
# 95     [April, 29,, 2019]  https://www.ratemds.com/doctor-ratings/3207299...
# 96     [August, 4,, 2018]  https://www.ratemds.com/doctor-ratings/3207299...
# 97      [June, 11,, 2018]  https://www.ratemds.com/doctor-ratings/3207299...
# 98   [February, 8,, 2018]  https://www.ratemds.com/doctor-ratings/3207299...
# 99                 [2018]  https://www.ratemds.com/doctor-ratings/3207299...
#
# [100 rows x 11 columns]

# %%
df_links.head(12020)
# Out:
#                       Name                             Speciality Star Rating  \
# 0      Dr. Natan Schleider                   Family Doctor / G.P.        5.00
# 1      Dr. Natan Schleider                   Family Doctor / G.P.        5.00
# 2      Dr. Natan Schleider                   Family Doctor / G.P.        5.00
# 3      Dr. Natan Schleider                   Family Doctor / G.P.        5.00
# 4      Dr. Natan Schleider                   Family Doctor / G.P.        4.00
# ...                    ...                                    ...         ...
# 12015      Dr. Trevor Born  Plastic / Cosmetic Surgeon, Physician        5.00
# 12016      Dr. Trevor Born  Plastic / Cosmetic Surgeon, Physician        5.00
# 12017      Dr. Trevor Born  Plastic / Cosmetic Surgeon, Physician        4.75
# 12018      Dr. Trevor Born  Plastic / Cosmetic Surgeon, Physician        5.00
# 12019      Dr. Trevor Born  Plastic / Cosmetic Surgeon, Physician        3.50
#
#       Staff Punctuality Helpfulness Knowledge  \
# 0         5           5           5         5
# 1         5           5           5         5
# 2         5           5           5         5
# 3         5           5           5         5
# 4         5           5           5         1
# ...     ...         ...         ...       ...
# 12015     5           5           5         5
# 12016     5           4           5         5
# 12017     4           3           2         2
# 12018     5           5           5         5
# 12019     5           5           5         5
#
#                                                  comment Rating Usefulness  \
# 0      I thought Dr. Schleider was extremely caring a...               [0]
# 1      Dr. Schleider was friendly, punctual, and supe...               [0]
# 2      My experience with Dr. Schleider was the oppos...               [0]
# 3      very good. Very knowledgeable and friendly wit...               [0]
# 4      Dr. Schleider is very knowledgeable and friend...               [0]
# ...                                                  ...               ...
# 12015  Dr Born and his staff are very knowledgeable a...               [0]
# 12016  What a wonderful experience working with Dr. T...               [1]
# 12017  I had a breast augmentation at Dr. Born's Toro...               [0]
# 12018  I had breast augmentation performed at Dr. Bor...               [0]
# 12019  I had a consultation with Dr Born for a rhinop...               [3]
#
#                   Review Date  \
# 0       [November, 20,, 2019]
# 1            [July, 7,, 2019]
# 2         [January, 2,, 2019]
# 3          [August, 9,, 2017]
# 4        [November, 8,, 2015]
# ...                       ...
# 12015  [September, 25,, 2018]
# 12016  [September, 24,, 2018]
# 12017  [September, 17,, 2018]
# 12018  [September, 16,, 2018]
# 12019     [August, 17,, 2018]
#
#                                                     Link
# 0      https://www.ratemds.com/doctor-ratings/20189/D...
# 1      https://www.ratemds.com/doctor-ratings/20189/D...
# 2      https://www.ratemds.com/doctor-ratings/20189/D...
# 3      https://www.ratemds.com/doctor-ratings/20189/D...
# 4      https://www.ratemds.com/doctor-ratings/20189/D...
# ...                                                  ...
# 12015  https://www.ratemds.com/doctor-ratings/49409/D...
# 12016  https://www.ratemds.com/doctor-ratings/49409/D...
# 12017  https://www.ratemds.com/doctor-ratings/49409/D...
# 12018  https://www.ratemds.com/doctor-ratings/49409/D...
# 12019  https://www.ratemds.com/doctor-ratings/49409/D...
#
# [12020 rows x 11 columns]

# %%
df_links.to_csv(r'review_dataset.new.1.csv', encoding='utf8')

# %%
df.to_csv(r'review_dataset.new.2.csv', encoding='utf8')

# %%
import os
desktop = os.path.expanduser("~/Desktop")

# %%
os.getcwd()
# Out:
# '/Users/lurui/Desktop'

# %%
os.chdir('/Users/lurui/Desktop')

# %%
df.to_csv(r'dataset.overall.csv', encoding='utf8')
